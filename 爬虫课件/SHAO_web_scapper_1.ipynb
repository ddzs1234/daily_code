# %% [markdown]
# ##第一课.   什么是爬虫
# 批量抓取互联网上沉淀下来的数据

# %% [markdown]
# 爬虫能做什么?

# %% [markdown]
# ## 自动挂号软件

# %%
from IPython.core.display import Image, display
#display(Image('./image/1.png', width=400, unconfined=True))
display(Image('./image/2.png', width=400, unconfined=True))

# %% [markdown]
# ## 分析淘宝商品销量

# %%
from IPython.core.display import Image, display
display(Image('./image/3.png', width=400, unconfined=True))
display(Image('./image/4.png', width=400, unconfined=True))

# %% [markdown]
# ## 分析房价趋势

# %%
from IPython.core.display import Image, display
display(Image('./image/5.png', width=400, unconfined=True))
display(Image('./image/6.png', width=400, unconfined=True))

# %% [markdown]
# * 爬取公众号文章
# http://dl.manmanqiusuo.com/gzh/shuiku/dir.html

# %% [markdown]
# 还可以用来抓抖音上的美女图片?
# https://github.com/wangshub/Douyin-Bot
