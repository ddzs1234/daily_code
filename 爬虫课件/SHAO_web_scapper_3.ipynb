# %% [markdown]
# * 爬虫技术简介
# 爬虫是 模拟用户在浏览器或者某个应用上的操作，把操作的过程、实现自动化的程序

# %% [markdown]
# 当我们在浏览器中输入一个url后回车，后台会发生什么？
# 比如说你输入http://www.zhihu.com/special/19855584

# %% [markdown]
# 1. 地址解析。
# 协议名：http 主机名：www.zhihu.com 端口：443 对象路径：/special/19855584

# %% [markdown]
# 2 DNS解析
# DNS简介，为什么需要DNS

# %% [markdown]
# 3. 组装HTTP请求包
# 请求包中需要包括 协议名，请求的资源名字, 请求方式(get, post),cookie, 接受什么语言编码, user-agent等

# %% [markdown]
# 4. TCP连接
# TCP和HTTP的关系, TCP 的握手连接

# %% [markdown]
# 5. 浏览器发送组装好的数据

# %% [markdown]
# 6. 服务器找到对应的资源，将浏览器想要的数据返回给浏览器

# %% [markdown]
#  ### https 又是什么?
# 1. Https 增加了server身份的鉴定机制, server需要有特殊的证书，才能别客户端信任，所有银行等重要知名机构，都是采用https的
# 2. https的数据内容不会被监听到

# %% [markdown]
# 怎样在chrome中观察http协议?

# %% [markdown]
# 状态码用来告诉HTTP客户端,HTTP服务器是否产生了预期的Response.
# HTTP/1.1中定义了5类状态码， 状态码由三位数字组成，第一个数字定义了响应的类别
# 1XX 提示信息 - 表示请求已被成功接收，继续处理
# 2XX 成功 - 表示请求已被成功接收，理解，接受
# 3XX 重定向 - 要完成请求必须进行更进一步的处理
# 4XX 客户端错误 - 请求有语法错误或请求无法实现
# 5XX 服务器端错误 - 服务器未能实现合法的请求

# %% [markdown]
# 最常用的响应状态码
# ◆200 (OK): 找到了该资源，并且一切正常。
# ◆301(Moved Permanently): 客户请求的文档在其他地方，新的URL在Location头中给出，浏览器应该自动地访问新的URL。
# ◆302 (Found): 类似于301，但新的URL应该被视为临时性的替代，而不是永久性的。
# ◆304 (NOT MODIFIED): 该资源在上次请求之后没有任何修改。这通常用于浏览器的缓存机制。
# ◆400 (Bad Request): 请求出现语法错误。
# ◆403 (FORBIDDEN): 客户端未能获得授权。这通常是在401之后输入了不正确的用户名或密码。
# ◆404 (NOT FOUND): 在指定的位置不存在所申请的资源。
# ◆500 (Internal Server Error): 服务器遇到了意料不到的情况，不能完成客户的请求
# ◆503 (Service Unavailable): 服务器由于维护或者负载过重未能应答。例如，Servlet可能在数据库连接池已满的情况下返回503。服务器返回503时可以提供一个Retry-After头

# %% [markdown]
#     爬虫的原理
# 就是模拟浏览器正常获取数据的方式，获得自己想要的数据

# %%
from IPython.core.display import Image, display
display(Image('./image/7.png', width=400, unconfined=True))
